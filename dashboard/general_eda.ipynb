# %%
import pandas as pd
import os

files = [
    "orders.csv",
    "order_items.csv",
    "products.csv",
    "product_variants.csv",
    "categories.csv",
    "customers.csv",
    "returns.csv",
    "return_items.csv",
    "stock_levels.csv",
]

for file in files:
    path = os.path.join("../data", file)

    df = pd.read_csv(path, nrows=5)

    print("\n" + "=" * 60)
    print(file)
    print("=" * 60)
    print(df.columns.tolist())
    print(df.head(2))
# Out:
# ...
# orders.csv
# ...
# ['id', 'order_number', 'channel', 'customer_id', 'salesperson_id', 'location_id', 'status', 'subtotal', 'discount_amount', 'total', 'placed_at', 'created_at', 'updated_at']
#    id order_number    channel  customer_id  salesperson_id  location_id  \
# 0   1    SO-000001  ecommerce         1136             NaN            1
# 1   2    SO-000002  ecommerce          618             9.0            4
#
#   status  subtotal  discount_amount     total            placed_at  \
# 0   paid    323.34            35.57    287.77  2022-09-06 05:37:37
# 1   paid  53199.05             0.00  53199.05  2023-02-03 04:36:21
#
#             created_at           updated_at
# 0  2022-09-06 05:37:37  2022-09-06 05:37:37
# 1  2023-02-03 04:36:21  2023-02-03 04:36:21
#
# ...
# order_items.csv
# ...
# ['id', 'order_id', 'product_variant_id', 'quantity', 'unit_price', 'icms_rate', 'ipi_rate', 'line_total']
#    id  order_id  product_variant_id  quantity  unit_price  icms_rate  \
# ...
